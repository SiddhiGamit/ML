# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('airline-passenger-traffic.csv', header = None)

# %%
df
# Out:
#            0      1
# 0    1949-01  112.0
# 1    1949-02  118.0
# 2    1949-03  132.0
# 3    1949-04  129.0
# 4    1949-05  121.0
# ..       ...    ...
# 139  1960-08  606.0
# 140  1960-09  508.0
# 141  1960-10  461.0
# 142  1960-11  390.0
# 143  1960-12  432.0
#
# [144 rows x 2 columns]

# %%
df.columns = ['Months', 'Passengers']

# %%
df['Months'] = pd.to_datetime(df['Months'], format = '%Y-%m')

# %%
df
# Out:
#         Months  Passengers
# 0   1949-01-01       112.0
# 1   1949-02-01       118.0
# 2   1949-03-01       132.0
# 3   1949-04-01       129.0
# 4   1949-05-01       121.0
# ..         ...         ...
# 139 1960-08-01       606.0
# 140 1960-09-01       508.0
# 141 1960-10-01       461.0
# 142 1960-11-01       390.0
# 143 1960-12-01       432.0
#
# [144 rows x 2 columns]

# %%
df = df.set_index('Months')

# %%
df.plot(figsize=(12,4))
plt.legend(loc = 'best')
plt.title('Airline Passenger Traffic')
plt.show()

# %%
# Linear Inter Polation
df['Passengers'] = df['Passengers'].interpolate(method = 'linear')

# %%
df.plot(figsize = (12,4))
plt.legend(loc = 'best')
plt.title('Airline Passenger Traffic')
plt.show()

# %%
plt.boxplot(df['Passengers'])
plt.show()

# %%
plt.hist(df['Passengers'])
plt.show()

# %%
import statsmodels.api as sm

# %%
#from statsmodels.api.tsa

# %%
decomposition = sm.tsa.seasonal_decompose(df.Passengers, model = 'additive')
fig = decomposition.plot()
plt.show()

# %%
decomposition = sm.tsa.seasonal_decompose(df.Passengers, model = 'multiplicative')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ## Split the time series

# %%
train_len = 120

# %%
train = df[0:train_len]
test = df[train_len:]

# %% [markdown]
# ## Simple Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
model = SimpleExpSmoothing(train['Passengers'])
# Out:
# C:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit(smoothing_level=0.2, optimized=False)

# %%
model_fit.params
# Out:
# {'smoothing_level': 0.2,
#  'smoothing_trend': None,
#  'smoothing_seasonal': None,
#  'damping_trend': nan,
#  'initial_level': 112.0,
#  'initial_trend': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
y_pred = model_fit.forecast(24)

# %%
y_pred
# Out:
# 1959-01-01    374.897327
# 1959-02-01    374.897327
# 1959-03-01    374.897327
# 1959-04-01    374.897327
# 1959-05-01    374.897327
# 1959-06-01    374.897327
# 1959-07-01    374.897327
# 1959-08-01    374.897327
# 1959-09-01    374.897327
# 1959-10-01    374.897327
# 1959-11-01    374.897327
# 1959-12-01    374.897327
# 1960-01-01    374.897327
# 1960-02-01    374.897327
# 1960-03-01    374.897327
# 1960-04-01    374.897327
# 1960-05-01    374.897327
# 1960-06-01    374.897327
# 1960-07-01    374.897327
# 1960-08-01    374.897327
# 1960-09-01    374.897327
# 1960-10-01    374.897327
# 1960-11-01    374.897327
# 1960-12-01    374.897327
# Freq: MS, dtype: float64

# %%
test['Passengers']
# Out:
# Months
# 1959-01-01    360.0
# 1959-02-01    342.0
# 1959-03-01    406.0
# 1959-04-01    396.0
# 1959-05-01    420.0
# 1959-06-01    472.0
# 1959-07-01    548.0
# 1959-08-01    559.0
# 1959-09-01    463.0
# 1959-10-01    407.0
# 1959-11-01    362.0
# 1959-12-01    405.0
# 1960-01-01    417.0
# 1960-02-01    391.0
# 1960-03-01    426.0
# 1960-04-01    461.0
# 1960-05-01    472.0
# 1960-06-01    535.0
# 1960-07-01    622.0
# 1960-08-01    606.0
# 1960-09-01    508.0
# 1960-10-01    461.0
# 1960-11-01    390.0
# 1960-12-01    432.0
# Name: Passengers, dtype: float64

# %%
plt.figure(figsize = (12, 4))
plt.plot(train['Passengers'], label = 'Train')
plt.plot(test['Passengers'], label = 'Test')
plt.plot(test['Passengers'], label = 'Simple')
plt.legend(loc ='best')
plt.title('Simple  Exponential Smoothing Method')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

# %%
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_pred)).round(2)

# %%
rmse
# Out:
# 107.65

# %%
mape = np.round(np.mean(np.abs(test['Passengers'] - y_pred)/test['Passengers'])*100,2)

# %%
mape
# Out:
# 16.49

# %%
results = pd.DataFrame({'Method':['Simple  Exponential Smoothing Method'], 'MAPE': [mape], 'RMSE': [rmse]})
results = results[['Method', 'RMSE', 'MAPE']]
results
# Out:
#                                  Method    RMSE   MAPE
# 0  Simple  Exponential Smoothing Method  107.65  16.49

# %% [markdown]
# ## Exponential Smoothing Mothods

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
model = ExponentialSmoothing(train['Passengers'],seasonal_periods=12,trend="multiplicative")
# Out:
# C:\Anaconda\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit(smoothing_level = 0.2, smoothing_slope = 0.01, optimized = False)

# %%
model.params
# Out:
# {'smoothing_level': 0.2,
#  'smoothing_trend': 0.01,
#  'smoothing_seasonal': None,
#  'damping_trend': nan,
#  'initial_level': 118.4666666666666,
#  'initial_trend': 1.01739397349977,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
y_pred = model_fit.forecast(len(test))

# %%
y_pred
# Out:
# 1959-01-01    400.633362
# 1959-02-01    405.431430
# 1959-03-01    410.286960
# 1959-04-01    415.200641
# 1959-05-01    420.173169
# 1959-06-01    425.205249
# 1959-07-01    430.297595
# 1959-08-01    435.450927
# 1959-09-01    440.665977
# 1959-10-01    445.943483
# 1959-11-01    451.284194
# 1959-12-01    456.688866
# 1960-01-01    462.158266
# 1960-02-01    467.693168
# 1960-03-01    473.294358
# 1960-04-01    478.962628
# 1960-05-01    484.698783
# 1960-06-01    490.503636
# 1960-07-01    496.378008
# 1960-08-01    502.322733
# 1960-09-01    508.338653
# 1960-10-01    514.426622
# 1960-11-01    520.587500
# 1960-12-01    526.822163
# Freq: MS, dtype: float64

# %%
plt.figure(figsize=(12,4))
plt.plot( train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_pred, label='Holt\'s exponential smoothing forecast')
plt.legend(loc='best')
plt.title('Holt\'s Exponential Smoothing Method')
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_pred)).round(2)

# %%
rmse
# Out:
# 70.14

# %%
mape = np.round(np.mean(np.abs(test['Passengers']-y_pred)/test['Passengers'])*100,2)

# %%
mape
# Out:
# 12.58

# %%
Result2 = pd.DataFrame({'Method':['Holt\'s  Exponential Smoothing Method'], 'RMSE': [rmse],'MAPE': [mape] })
results = pd.concat([results, Result2])
results = results[['Method', 'RMSE', 'MAPE']]
results
# Out:
#                                  Method    RMSE   MAPE
# 0  Simple  Exponential Smoothing Method  107.65  16.49
# 0  Holt's  Exponential Smoothing Method   70.14  12.58

# %% [markdown]
# ##  Holt winters

# %%
model = ExponentialSmoothing(np.asarray(train['Passengers']) ,seasonal_periods=12 ,trend='mul', seasonal='mul')

# %%
model_fit = model.fit(optimized=True)

# %%
print(model_fit.params)
# Out:
# {'smoothing_level': 0.3863442679018671, 'smoothing_trend': 1.8061438231937075e-09, 'smoothing_seasonal': 0.6136557316369492, 'damping_trend': nan, 'initial_level': 110.84662595206673, 'initial_trend': 1.009663306939697, 'initial_seasons': array([1.00073971, 1.0572128 , 1.16732649, 1.10715476, 1.01524717,
#        1.11167911, 1.21361244, 1.20645475, 1.09715002, 0.95080144,
#        0.84217555, 0.98245748]), 'use_boxcox': False, 'lamda': None, 'remove_bias': False}

# %%
y_pred = model_fit.forecast(24)

# %%
y_pred
# Out:
# array([353.73593621, 337.57974446, 393.95509341, 387.76267104,
#        407.33768303, 488.26040909, 546.08973803, 550.3954266 ,
#        447.03882951, 395.6560341 , 343.37470063, 386.37407379,
#        397.00690869, 378.87440055, 442.14589977, 435.19598541,
#        457.16552314, 547.98717293, 612.89051117, 617.72289582,
#        501.72313752, 444.05490911, 385.3782284 , 433.63752713])

# %%
plt.figure(figsize=(12,4))
plt.grid()
plt.plot( train['Passengers'], label='Train')
plt.plot(test['Passengers'], label='Test')
plt.plot(y_pred, label='Holt Winters\'s additive forecast')
plt.legend(loc='best')
plt.title('Holt Winters\' Additive Method')
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(test['Passengers'], y_pred)).round(2)

# %%
rmse
# Out:
# 13.36

# %%
mape = np.round(np.mean(np.abs(test['Passengers'] -y_pred)/test['Passengers'])*100,2)

# %%
mape
# Out:
# 2.71

# %%
Result3 = pd.DataFrame({'Method':['Holt\'s Winter  Exponential Smoothing Method'], 'RMSE': [rmse],'MAPE': [mape] })
results = pd.concat([results, Result3])
results = results[['Method', 'RMSE', 'MAPE']]
results
# Out:
#                                         Method    RMSE   MAPE
# 0         Simple  Exponential Smoothing Method  107.65  16.49
# 0         Holt's  Exponential Smoothing Method   70.14  12.58
# 0  Holt's Winter  Exponential Smoothing Method   13.36   2.71
