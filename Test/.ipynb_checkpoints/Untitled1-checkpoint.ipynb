# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('churn_data.csv')

# %%
df.head()
# Out:
#    customerID  tenure PhoneService        Contract PaperlessBilling  \
# 0  7590-VHVEG       1           No  Month-to-month              Yes
# 1  5575-GNVDE      34          Yes        One year               No
# 2  3668-QPYBK       2          Yes  Month-to-month              Yes
# 3  7795-CFOCW      45           No        One year               No
# 4  9237-HQITU       2          Yes  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df.isnull().sum()
# Out:
# customerID          0
# tenure              0
# PhoneService        0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# customerID           object
# tenure                int64
# PhoneService         object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df. drop(['customerID'], axis = 1 , inplace = True) # drop customer ID

# %%
df.sample(5)
# Out:
#       tenure PhoneService        Contract PaperlessBilling  \
# 5262      59          Yes        One year               No
# 190       43          Yes        One year              Yes
# 6029       4          Yes  Month-to-month              Yes
# 775       72          Yes        Two year              Yes
# 1613      34          Yes  Month-to-month               No
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 5262  Bank transfer (automatic)           68.70      4070.95    No
# 190     Credit card (automatic)           71.90      3173.35    No
# 6029               Mailed check           94.90       360.55    No
# 775     Credit card (automatic)          110.65      8065.65    No
# 1613               Mailed check           19.70        675.6    No

# %%
df[df["TotalCharges"] == " "]
# Out:
#       tenure PhoneService  Contract PaperlessBilling  \
# 488        0           No  Two year              Yes
# 753        0          Yes  Two year               No
# 936        0          Yes  Two year               No
# 1082       0          Yes  Two year               No
# 1340       0           No  Two year               No
# 3331       0          Yes  Two year               No
# 3826       0          Yes  Two year               No
# 4380       0          Yes  Two year               No
# 5218       0          Yes  One year              Yes
# 6670       0          Yes  Two year               No
# 6754       0          Yes  Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 488   Bank transfer (automatic)           52.55                 No
# 753                Mailed check           20.25                 No
# 936                Mailed check           80.85                 No
# 1082               Mailed check           25.75                 No
# 1340    Credit card (automatic)           56.05                 No
# 3331               Mailed check           19.85                 No
# 3826               Mailed check           25.35                 No
# 4380               Mailed check           20.00                 No
# 5218               Mailed check           19.70                 No
# 6670               Mailed check           73.35                 No
# 6754  Bank transfer (automatic)           61.90                 No

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Heatmap

# %%
cor = df.corr()
sns.heatmap(cor, annot = True)
plt.show()

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
df['PaperlessBilling'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
df['PhoneService'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64

# %%
df['PhoneService'].map({'yes' : 1, 'no' : 0})
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 7038   NaN
# 7039   NaN
# 7040   NaN
# 7041   NaN
# 7042   NaN
# Name: PhoneService, Length: 7043, dtype: float64

# %%
df.sample(10)
# Out:
#       tenure PhoneService        Contract PaperlessBilling  \
# 1582      56          Yes        One year               No
# 2535      70          Yes        Two year              Yes
# 3587       9          Yes  Month-to-month              Yes
# 3597      25          Yes  Month-to-month              Yes
# 5620      72          Yes        Two year              Yes
# 6882      71          Yes        One year              Yes
# 4557      53           No        One year               No
# 2528       8          Yes  Month-to-month              Yes
# 1701      66          Yes        One year              Yes
# 5449      67          Yes        Two year               No
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 1582  Bank transfer (automatic)           65.20      3512.15    No
# 2535  Bank transfer (automatic)           92.20      6474.45    No
# 3587    Credit card (automatic)           99.45        919.4   Yes
# 3597    Credit card (automatic)           95.70      2338.35    No
# 5620  Bank transfer (automatic)          104.80       7470.1    No
# 6882    Credit card (automatic)           99.65      7181.25    No
# 4557    Credit card (automatic)           54.90      3045.75    No
# 2528  Bank transfer (automatic)           80.10        679.3   Yes
# 1701    Credit card (automatic)          102.45      6615.15   Yes
# 5449  Bank transfer (automatic)          103.15       6895.5    No

# %% [markdown]
# ## Dummy Variable

# %%
status = pd.get_dummies(df['Contract'])

# %%
status.sample(5)
# Out:
#       Month-to-month  One year  Two year
# 1750               0         0         1
# 1384               1         0         0
# 405                0         0         1
# 920                0         1         0
# 4356               1         0         0

# %%
status = pd.get_dummies(df['Contract'], drop_first = True)

# %%
status.sample(5)
# Out:
#       One year  Two year
# 5608         1         0
# 4323         1         0
# 2221         0         1
# 5749         1         0
# 1093         0         1

# %%
status = pd.get_dummies(df['Contract'], drop_first = True)

# %%
df = pd.concat([df, status], axis = 1)

# %%
status.sample(5)
# Out:
#       One year  Two year
# 6079         0         0
# 6849         0         0
# 3000         0         0
# 705          0         0
# 4348         0         0

# %%
df.drop(['Contract'], axis = 1, inplace = True)

# %%
df.sample(5)
# Out:
#       tenure PhoneService PaperlessBilling              PaymentMethod  \
# 973       44           No              Yes           Electronic check
# 109       72          Yes               No    Credit card (automatic)
# 5472      24          Yes               No  Bank transfer (automatic)
# 3219      24          Yes               No               Mailed check
# 3141       2          Yes              Yes    Credit card (automatic)
#
#       MonthlyCharges TotalCharges Churn  One year  Two year
# 973            30.35       1359.7   Yes         0         0
# 109            19.40      1363.25    No         0         1
# 5472           81.00      1923.85    No         0         0
# 3219           24.70       571.75    No         0         1
# 3141           95.10       180.25   Yes         0         0

# %% [markdown]
# ### Dummy : Payment Method

# %%
status = pd.get_dummies(df['PaymentMethod'])

# %%
status.sample(5)
# Out:
#       Bank transfer (automatic)  Credit card (automatic)  Electronic check  \
# 6161                          0                        0                 0
# 3557                          1                        0                 0
# 649                           0                        1                 0
# 4775                          0                        1                 0
# 3289                          1                        0                 0
#
#       Mailed check
# 6161             1
# 3557             0
# 649              0
# 4775             0
# 3289             0

# %%
status = pd.get_dummies(df['PaymentMethod'], drop_first = True)

# %%
df = pd.concat([df, status], axis = 1)

# %%
df.drop(['PaymentMethod'], axis = 1, inplace = True)

# %%
df.sample(5)
# Out:
#       tenure PhoneService PaperlessBilling  MonthlyCharges TotalCharges Churn  \
# 6038      70          Yes              Yes          114.20       7723.9   Yes
# 3261      68          Yes              Yes           85.00      5607.75    No
# 3089      68          Yes              Yes           82.45       5646.6    No
# 4730      31          Yes              Yes           96.60      2877.95    No
# 4671      25          Yes              Yes          100.25      2387.75   Yes
#
#       One year  Two year  Credit card (automatic)  Electronic check  \
# 6038         0         1                        0                 0
# 3261         0         1                        1                 0
# 3089         0         1                        1                 0
# 4730         0         0                        0                 0
# 4671         0         0                        0                 1
#
#       Mailed check
# 6038             0
# 3261             0
# 3089             0
# 4730             0
# 4671             0

# %%
varlist = ['PhoneService','PaperlessBilling','Churn']
 
def binary_map(x):
    return x.map({'yes' : 1, 'no' : 0})

df[varlist] = df[varlist].apply(binary_map)
