# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
train.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1199  1200          20       RL         75.0    11235   Pave   NaN      Reg
# 151    152          20       RL        107.0    13891   Pave   NaN      Reg
# 1380  1381          30       RL         45.0     8212   Pave  Grvl      Reg
# 21      22          45       RM         57.0     7449   Pave  Grvl      Reg
# 240    241          20       FV         75.0     9000   Pave   NaN      Reg
# 1256  1257          20       RL         91.0    14303   Pave   NaN      IR1
# 1392  1393          85       RL         68.0     7838   Pave   NaN      Reg
# 980    981          85       RL          NaN    12122   Pave   NaN      IR1
# 311    312          20       RL         50.0     8000   Pave   NaN      Reg
# 1084  1085          60       RL          NaN    13031   Pave   NaN      IR2
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1199         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 151          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1380         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 21           Bnk    AllPub  ...        0    NaN  GdPrv         NaN       0
# 240          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1256         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1392         Lvl    AllPub  ...        0    NaN   MnWw         NaN       0
# 980          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 311          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1084         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1199     10   2006        WD         Normal     148000
# 151       1   2008       New        Partial     372402
# 1380      6   2010        WD         Normal      58500
# 21        6   2007        WD         Normal     139400
# 240       4   2010        WD         Normal     262500
# 1256      8   2008        WD         Normal     301500
# 1392     12   2006        WD         Normal     123000
# 980       7   2008        WD         Normal     178400
# 311       5   2009        WD         Normal     132000
# 1084      7   2006        WD         Normal     187500
#
# [10 rows x 81 columns]

# %%
    train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train.isnull().sum().sort_values(ascending = False)
# Out:
# PoolQC         1453
# MiscFeature    1406
# Alley          1369
# Fence          1179
# FireplaceQu     690
#                ...
# ExterQual         0
# Exterior2nd       0
# Exterior1st       0
# RoofMatl          0
# SalePrice         0
# Length: 81, dtype: int64

# %%
np.round(((train.isnull().sum()/len(train))*100).sort_values(ascending = False),2)
# Out:
# PoolQC         99.52
# MiscFeature    96.30
# Alley          93.77
# Fence          80.75
# FireplaceQu    47.26
#                ...
# ExterQual       0.00
# Exterior2nd     0.00
# Exterior1st     0.00
# RoofMatl        0.00
# SalePrice       0.00
# Length: 81, dtype: float64

# %% [markdown]
# # Treating Missing Values

# %%
cm = sns.light_palette("green", as_cmap=True)
train.head(20).style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_e267f_row0_col0, #T_e267f_row0_col18, #T_e267f_row0_col36, #T_e267f_row0_col45, #T_e267f_row0_col48, #T_e267f_row0_col52, #T_e267f_row0_col56, #T_e267f_row0_col66, #T_e267f_row0_col68, #T_e267f_row0_col69, #T_e267f_row0_col70, #T_e267f_row0_col71, #T_e267f_row0_col75, #T_e267f_row1_col1, #T_e267f_row1_col26, #T_e267f_row1_col36, #T_e267f_row1_col44, #T_e267f_row1_col45, #T_e267f_row1_col47, #T_e267f_row1_col50, #T_e267f_row1_col52, #T_e267f_row1_col67, #T_e267f_row1_col68, #T_e267f_row1_col69, #T_e267f_row1_col70, #T_e267f_row1_col71, #T_e267f_row1_col75, #T_e267f_row2_col18, #T_e267f_row2_col36, #T_e267f_row2_col45, #T_e267f_row2_col48, #T_e267f_row2_col52, #T_e267f_row2_col66, #T_e267f_row2_col68, #T_e267f_row2_col69, #T_e267f_row2_col70, #T_e267f_row2_col71, #T_e267f_row2_col75, #T_e267f_row3_col18, #T_e267f_row3_col19, #T_e267f_row3_col26, #T_e267f_row3_col36, #T_e267f_row3_col45, #T_e267f_row3_col48, #T_e267f_row3_col49, #T_e267f_row3_col50, #T_e267f_row3_col52, #T_e267f_row3_col66, #T_e267f_row3_col69, #T_e267f_row3_col70, #T_e267f_row3_col71, #T_e267f_row3_col75, #T_e267f_row3_col77, #T_e267f_row4_col18, #T_e267f_row4_col36, #T_e267f_row4_col45, #T_e267f_row4_col48, #T_e267f_row4_col52, #T_e267f_row4_col68, #T_e267f_row4_col69, #T_e267f_row4_col70, #T_e267f_row4_col71, #T_e267f_row4_col75, #T_e267f_row5_col18, #T_e267f_row5_col26, #T_e267f_row5_col36, #T_e267f_row5_col43, #T_e267f_row5_col45, #T_e267f_row5_col48, #T_e267f_row5_col49, #T_e267f_row5_col51, #T_e267f_row5_col52, #T_e267f_row5_col56, #T_e267f_row5_col68, #T_e267f_row5_col70, #T_e267f_row5_col71, #T_e267f_row6_col1, #T_e267f_row6_col18, #T_e267f_row6_col36, #T_e267f_row6_col44, #T_e267f_row6_col45, #T_e267f_row6_col48, #T_e267f_row6_col50, #T_e267f_row6_col52, #T_e267f_row6_col68, #T_e267f_row6_col69, #T_e267f_row6_col70, #T_e267f_row6_col71, #T_e267f_row6_col75, #T_e267f_row7_col45, #T_e267f_row7_col48, #T_e267f_row7_col52, #T_e267f_row7_col69, #T_e267f_row7_col70, #T_e267f_row7_col71, #T_e267f_row8_col4, #T_e267f_row8_col18, #T_e267f_row8_col20, #T_e267f_row8_col26, #T_e267f_row8_col34, #T_e267f_row8_col36, #T_e267f_row8_col45, #T_e267f_row8_col47, #T_e267f_row8_col48, #T_e267f_row8_col50, #T_e267f_row8_col59, #T_e267f_row8_col67, #T_e267f_row8_col69, #T_e267f_row8_col70, #T_e267f_row8_col71, #T_e267f_row8_col75, #T_e267f_row9_col3, #T_e267f_row9_col20, #T_e267f_row9_col26, #T_e267f_row9_col36, #T_e267f_row9_col44, #T_e267f_row9_col45, #T_e267f_row9_col48, #T_e267f_row9_col49, #T_e267f_row9_col50, #T_e267f_row9_col61, #T_e267f_row9_col62, #T_e267f_row9_col66, #T_e267f_row9_col68, #T_e267f_row9_col69, #T_e267f_row9_col70, #T_e267f_row9_col71, #T_e267f_row9_col75, #T_e267f_row9_col76, #T_e267f_row10_col1, #T_e267f_row10_col18, #T_e267f_row10_col26, #T_e267f_row10_col36, #T_e267f_row10_col44, #T_e267f_row10_col45, #T_e267f_row10_col48, #T_e267f_row10_col49, #T_e267f_row10_col50, #T_e267f_row10_col52, #T_e267f_row10_col56, #T_e267f_row10_col61, #T_e267f_row10_col66, #T_e267f_row10_col67, #T_e267f_row10_col68, #T_e267f_row10_col69, #T_e267f_row10_col70, #T_e267f_row10_col71, #T_e267f_row10_col75, #T_e267f_row11_col18, #T_e267f_row11_col36, #T_e267f_row11_col45, #T_e267f_row11_col48, #T_e267f_row11_col50, #T_e267f_row11_col52, #T_e267f_row11_col68, #T_e267f_row11_col69, #T_e267f_row11_col70, #T_e267f_row11_col71, #T_e267f_row11_col75, #T_e267f_row11_col77, #T_e267f_row12_col1, #T_e267f_row12_col26, #T_e267f_row12_col36, #T_e267f_row12_col44, #T_e267f_row12_col45, #T_e267f_row12_col48, #T_e267f_row12_col49, #T_e267f_row12_col50, #T_e267f_row12_col52, #T_e267f_row12_col54, #T_e267f_row12_col56, #T_e267f_row12_col61, #T_e267f_row12_col67, #T_e267f_row12_col68, #T_e267f_row12_col69, #T_e267f_row12_col71, #T_e267f_row12_col75, #T_e267f_row13_col1, #T_e267f_row13_col18, #T_e267f_row13_col34, #T_e267f_row13_col36, #T_e267f_row13_col44, #T_e267f_row13_col45, #T_e267f_row13_col47, #T_e267f_row13_col48, #T_e267f_row13_col50, #T_e267f_row13_col52, #T_e267f_row13_col68, # ...
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_e267f_row0_col1, #T_e267f_row2_col1, #T_e267f_row4_col1, #T_e267f_row7_col1, #T_e267f_row11_col1 {
#   background-color: #b3d8b3;
#   color: #000000;
# }
# #T_e267f_row0_col3, #T_e267f_row1_col76, #T_e267f_row14_col76, #T_e267f_row19_col76 {
#   background-color: #95c995;
#   color: #000000;
# }
# #T_e267f_row0_col4, #T_e267f_row0_col67, #T_e267f_row1_col54, #T_e267f_row2_col54, #T_e267f_row17_col54, #T_e267f_row18_col54, #T_e267f_row19_col54 {
#   background-color: #a7d2a7;
#   color: #000000;
# }
# #T_e267f_row0_col17, #T_e267f_row1_col59, #T_e267f_row2_col17, #T_e267f_row3_col17, #T_e267f_row7_col17, #T_e267f_row8_col17, #T_e267f_row13_col17, #T_e267f_row15_col17 {
#   background-color: #5eae5e;
#   color: #f1f1f1;
# }
# #T_e267f_row0_col19, #T_e267f_row6_col20 {
#   background-color: #078407;
#   color: #f1f1f1;
# }
# #T_e267f_row0_col20, #T_e267f_row2_col59, #T_e267f_row18_col4 {
#   background-color: #108810;
#   color: #f1f1f1;
# }
# #T_e267f_row0_col26, #T_e267f_row7_col59 {
#   background-color: #67b267;
#   color: #f1f1f1;
# }
# #T_e267f_row0_col34, #T_e267f_row1_col43, #T_e267f_row12_col19 {
#   background-color: #71b771;
#   color: #f1f1f1;
# }
# #T_e267f_row0_col37, #T_e267f_row11_col67 {
#   background-color: #d4e8d4;
#   color: #000000;
# }
# #T_e267f_row0_col38 {
#   background-color: #74b974;
#   color: #f1f1f1;
# }
# #T_e267f_row0_col43 {
#   background-color: #dbebdb;
#   color: #000000;
# }
# #T_e267f_row0_col44, #T_e267f_row1_col38 {
#   background-color: #3b9d3b;
#   color: #f1f1f1;
# }
# #T_e267f_row0_col46, #T_e267f_row15_col62, #T_e267f_row18_col62 {
#   background-color: #61b061;
#   color: #f1f1f1;
# }
# #T_e267f_row0_col47, #T_e267f_row0_col50,

# %%
isnull = train.isnull().sum().sort_values(ascending=False).to_frame()
isnull.columns = ['How_many']
isnull['precentage'] = np.around(((isnull / len(train) * 100)[(isnull / len(train) * 100) != 0]), decimals=2)
isnull[isnull.How_many > 0].style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_d6390_row0_col0, #T_d6390_row0_col1 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_d6390_row1_col0, #T_d6390_row1_col1 {
#   background-color: #078407;
#   color: #f1f1f1;
# }
# #T_d6390_row2_col0, #T_d6390_row2_col1 {
#   background-color: #0d860d;
#   color: #f1f1f1;
# }
# #T_d6390_row3_col0, #T_d6390_row3_col1 {
#   background-color: #2c962c;
#   color: #f1f1f1;
# }
# #T_d6390_row4_col0, #T_d6390_row4_col1 {
#   background-color: #7bbc7b;
#   color: #000000;
# }
# #T_d6390_row5_col0, #T_d6390_row5_col1 {
#   background-color: #c1dfc1;
#   color: #000000;
# }
# #T_d6390_row6_col0, #T_d6390_row6_col1, #T_d6390_row7_col0, #T_d6390_row7_col1, #T_d6390_row8_col0, #T_d6390_row8_col1, #T_d6390_row9_col0, #T_d6390_row9_col1, #T_d6390_row10_col0, #T_d6390_row10_col1 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_d6390_row11_col0, #T_d6390_row11_col1, #T_d6390_row12_col0, #T_d6390_row12_col1, #T_d6390_row13_col0, #T_d6390_row13_col1, #T_d6390_row14_col0, #T_d6390_row14_col1, #T_d6390_row15_col0, #T_d6390_row15_col1 {
#   background-color: #e5f0e5;
#   color: #000000;
# }
# #T_d6390_row16_col0, #T_d6390_row16_col1, #T_d6390_row17_col0, #T_d6390_row17_col1 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_d6390_row18_col0, #T_d6390_row18_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# </style>
# <table id="T_d6390">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6390_level0_col0" class="col_heading level0 col0" >How_many</th>
#       <th id="T_d6390_level0_col1" class="col_heading level0 col1" >precentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6390_level0_row0" class="row_heading level0 row0" >PoolQC</th>
#       <td id="T_d6390_row0_col0" class="data row0 col0" >1453</td>
#       <td id="T_d6390_row0_col1" class="data row0 col1" >99.520000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row1" class="row_heading level0 row1" >MiscFeature</th>
#       <td id="T_d6390_row1_col0" class="data row1 col0" >1406</td>
#       <td id="T_d6390_row1_col1" class="data row1 col1" >96.300000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row2" class="row_heading level0 row2" >Alley</th>
#       <td id="T_d6390_row2_col0" class="data row2 col0" >1369</td>
#       <td id="T_d6390_row2_col1" class="data row2 col1" >93.770000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row3" class="row_heading level0 row3" >Fence</th>
#       <td id="T_d6390_row3_col0" class="data row3 col0" >1179</td>
#       <td id="T_d6390_row3_col1" class="data row3 col1" >80.750000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row4" class="row_heading level0 row4" >FireplaceQu</th>
#       <td id="T_d6390_row4_col0" class="data row4 col0" >690</td>
#       <td id="T_d6390_row4_col1" class="data row4 col1" >47.260000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row5" class="row_heading level0 row5" >LotFrontage</th>
#       <td id="T_d6390_row5_col0" class="data row5 col0" >259</td>
#       <td id="T_d6390_row5_col1" class="data row5 col1" >17.740000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row6" class="row_heading level0 row6" >GarageYrBlt</th>
#       <td id="T_d6390_row6_col0" class="data row6 col0" >81</td>
#       <td id="T_d6390_row6_col1" class="data row6 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row7" class="row_heading level0 row7" >GarageCond</th>
#       <td id="T_d6390_row7_col0" class="data row7 col0" >81</td>
#       <td id="T_d6390_row7_col1" class="data row7 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row8" class="row_heading level0 row8" >GarageType</th>
#       <td id="T_d6390_row8_col0" class="data row8 col0" >81</td>
#       <td id="T_d6390_row8_col1" class="data row8 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row9" class="row_heading level0 row9" >GarageFinish</th>
#       <td id="T_d6390_row9_col0" class="data row9 col0" >81</td>
#       <td id="T_d6390_row9_col1" class="data row9 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row10" class="row_heading level0 row10" >GarageQual</th>
#       <td id="T_d6390_row10_col0" class="data row10 col0" >81</td>
#       <td id="T_d6390_row10_col1" class="data row10 col1" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row11" class="row_heading level0 row11" >BsmtFinType2</th>
#       <td id="T_d6390_row11_col0" class="data row11 col0" >38</td>
#       <td id="T_d6390_row11_col1" class="data row11 col1" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row12" class="row_heading level0 row12" >BsmtExposure</th>
#       <td id="T_d6390_row12_col0" class="data row12 col0" >38</td>
#       <td id="T_d6390_row12_col1" class="data row12 col1" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row13" class="row_heading level0 row13" >BsmtQual</th>
#       <td id="T_d6390_row13_col0" class="data row13 col0" >37</td>
#       <td id="T_d6390_row13_col1" class="data row13 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row14" class="row_heading level0 row14" >BsmtCond</th>
#       <td id="T_d6390_row14_col0" class="data row14 col0" >37</td>
#       <td id="T_d6390_row14_col1" class="data row14 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row15" class="row_heading level0 row15" >BsmtFinType1</th>
#       <td id="T_d6390_row15_col0" class="data row15 col0" >37</td>
#       <td id="T_d6390_row15_col1" class="data row15 col1" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row16" class="row_heading level0 row16" >MasVnrArea</th>
#       <td id="T_d6390_row16_col0" class="data row16 col0" >8</td>
#       <td id="T_d6390_row16_col1" class="data row16 col1" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row17" class="row_heading level0 row17" >MasVnrType</th>
#       <td id="T_d6390_row17_col0" class="data row17 col0" >8</td>
#       <td id="T_d6390_row17_col1" class="data row17 col1" >0.550000</td>
#     </tr>
#     <tr>
#       <th id="T_d6390_level0_row18" class="row_heading level0 row18" >Electrical</th>
#       <td id="T_d6390_row18_col0" class="data row18 col0" >1</td>
#       <td id="T_d6390_row18_col1" class="data row18 col1" >0.070000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## replace the null values in numeric columns with the mean of that column

# %% [markdown]
# ## LotFrontage column

# %%
train["LotFrontage"].isnull().sum()
# Out:
# 259

# %%
train['LotFrontage'].fillna(int(train['LotFrontage'].mean()), inplace=True)

# %%
train["LotFrontage"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## GarageYrBlt column

# %%
train["GarageYrBlt"].isnull().sum()
# Out:
# 81

# %%
train['GarageYrBlt'].fillna(int(train['GarageYrBlt'].mean()), inplace=True)

# %%
train["GarageYrBlt"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # drop null values in the columns that has a total number of missing data > 5

# %%
number_of_missing = train.isnull().sum().sort_values()
percent_of_missing = ((train.isnull().sum() / train.isnull().count())*100).sort_values()
missing_train_df = pd.concat([number_of_missing,  percent_of_missing], keys = ['total number of missing data', 'total percent of missing data'], axis = 1)
train = train.drop((missing_train_df[missing_train_df['total number of missing data'] > 5]).index, axis = 1)
train.isnull().sum().sort_values(ascending = False)
# Out:
# Electrical      1
# CentralAir      0
# 1stFlrSF        0
# 2ndFlrSF        0
# LowQualFinSF    0
#                ..
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# SalePrice       0
# Length: 65, dtype: int64

# %% [markdown]
# ## the columns that has <5 null values, we choose the most repeated value and fill the missing data with it

# %%
train['Electrical'].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
train['Electrical'].fillna(train['Electrical'].value_counts().index[0], inplace = True)

# %% [markdown]
# ## which feature has the maximum correlation with the Sale Price of the house?

# %%
max = 0
x=0
for i in train.select_dtypes(include=np.number).drop(['SalePrice'],axis=1).columns:
    if (train[i].corr(train['SalePrice'])) > max:
        max = train[i].corr(train['SalePrice'])
        x = i
print("The column which has the maximum correlation with the SalePrice is: {0}" .format(x))
# Out:
# The column which has the maximum correlation with the SalePrice is: OverallQual

# %% [markdown]
# ## Unique value in each columns

# %%
arr=[]
for i in train.columns:
    arr.append(len(train[i].value_counts()))
value_counts_df = pd.concat([pd.Series(train.columns), pd.Series(arr)], keys = ['column name', 'number of unique values in that column'], axis = 1)

value_counts_df
# Out:
#       column name  number of unique values in that column
# 0              Id                                    1460
# 1      MSSubClass                                      15
# 2        MSZoning                                       5
# 3     LotFrontage                                     110
# 4         LotArea                                    1073
# ..            ...                                     ...
# 60         MoSold                                      12
# 61         YrSold                                       5
# 62       SaleType                                       9
# 63  SaleCondition                                       6
# 64      SalePrice                                     663
#
# [65 rows x 2 columns]

# %%
value_counts_df.sort_values('number of unique values in that column').head(23)
# Out:
#      column name  number of unique values in that column
# 33    CentralAir                                       2
# 5         Street                                       2
# 8      Utilities                                       2
# 42      HalfBath                                       3
# 52    PavedDrive                                       3
# 40  BsmtHalfBath                                       3
# 10     LandSlope                                       3
# 45   KitchenQual                                       4
# 24     ExterQual                                       4
# 48    Fireplaces                                       4
# 39  BsmtFullBath                                       4
# 7    LandContour                                       4
# 6       LotShape                                       4
# 44  KitchenAbvGr                                       4
# 41      FullBath                                       4
# 61        YrSold                                       5
# 25     ExterCond                                       5
# 34    Electrical                                       5
# 32     HeatingQC                                       5
# 50    GarageCars                                       5
# 2       MSZoning                                       5
# 9      LotConfig                                       5
# 14      BldgType                                       5

# %% [markdown]
# ## what is the relation between Overall material and finish quality, sale price depending on Overall condition rating?

# %%
sns.lmplot(x='OverallQual', y='SalePrice', data=train ,hue='OverallCond',size=8)
# Out:
# C:\Users\siddh\anaconda3\anaconda\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## relation between grade (ground) living area square feet and Sale Price depending on general zoning

# %%
sns.lmplot(x='GrLivArea', y='SalePrice', data=train,col='MSZoning',size=10)
# Out:
# C:\Users\siddh\anaconda3\anaconda\lib\site-packages\seaborn\regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ## Numerical variables:

# %%
n_val = train.select_dtypes(exclude=['object']).drop(['MSSubClass'], axis=1).copy()
l=[]
for i in n_val:
  l.append(i)
print("Total no of numerical variables:",len(l))
# Out:
# Total no of numerical variables: 36

# %%
fig = plt.figure(figsize=(18,16))
for index,col in enumerate(n_val):
    plt.subplot(6,6,index+1)
    sns.distplot(n_val.loc[:,col].dropna(), kde=False,color= 'g')
fig.tight_layout(pad=1.0)

# %% [markdown]
# -From the given plots we can tell that certain numerical variables have only one kind of value:
# -BsmtFitSF2
# -LowQualFinSF
# -BSMHalfBath
# -KitchenAbvGr
# -EnclosedPorch
# -3snPorch
# -Screen Porch
# -PoolArea
# -MiscVal

# %% [markdown]
# ## Categorical Variables

# %%
c_val = train.select_dtypes(include=['object']).copy()
c_val['MSSubClass'] = train['MSSubClass']
print(c_val.columns)
l=[]
for i in c_val:
  l.append(i)
print("Total no of categorical variables:",len(l))
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional',
#        'PavedDrive', 'SaleType', 'SaleCondition', 'MSSubClass'],
#       dtype='object')
# Total no of categorical variables: 29

# %%
fig = plt.figure(figsize=(18,20))
for index in range(len(c_val.columns)):
    plt.subplot(9,5,index+1)
    sns.countplot(x=c_val.iloc[:,index], data=c_val.dropna())
    plt.xticks(rotation=90)
fig.tight_layout(pad=1.2)
